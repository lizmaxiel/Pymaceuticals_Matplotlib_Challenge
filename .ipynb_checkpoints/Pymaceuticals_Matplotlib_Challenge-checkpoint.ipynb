# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = 'data/Mouse_metadata.csv'
study_results_path = 'data/Study_results.csv'

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(study_results, mouse_metadata, how='left', on='Mouse ID')

# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice = combined_data['Mouse ID'].nunique()
mice
# Out:
# 249

# %%
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_id = combined_data[combined_data.duplicated(subset=['Mouse ID', 'Timepoint'], keep='first')]['Mouse ID'].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
#Get all the data for the duplicate mouse ID. 
duplicate = combined_data[combined_data['Mouse ID'] == 'g989']
duplicate
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_data = combined_data.drop_duplicates(subset='Mouse ID', keep='first')
clean_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice = clean_data['Mouse ID'].nunique()
clean_mice
# Out:
# 249

# %%
# Group the data by 'Drug Regimen'
grouped_data = combined_data.groupby('Drug Regimen')

# Calculate the mean, median, variance, standard deviation, and SEM for each drug regimen
mean_volume = grouped_data['Tumor Volume (mm3)'].mean()
median_volume = grouped_data['Tumor Volume (mm3)'].median()
variance_volume = grouped_data['Tumor Volume (mm3)'].var()
std_volume = grouped_data['Tumor Volume (mm3)'].std()
sem_volume = grouped_data['Tumor Volume (mm3)'].sem()

# Create a summary DataFrame with the calculated statistics
summary_df = pd.DataFrame({
    'Mean Tumor Volume': mean_volume,
    'Median Tumor Volume': median_volume,
    'Tumor Volume Variance': variance_volume,
    'Tumor Volume Std. Dev.': std_volume,
    'Tumor Volume Std. Err.': sem_volume})

summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Using the aggregation method, produce the same summary statistics in a single line
summary_df = grouped_data.agg({
    'Tumor Volume (mm3)': ['mean', 'median', 'var', 'std', 'sem']})
summary_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_count = combined_data[['Drug Regimen', 'Timepoint']]

mice_count = drug_count['Drug Regimen'].value_counts()

mice_count.plot(kind = 'bar', color = 'blue')
plt.title('Number of Rows for Each Drug Regimen') 
plt.xlabel('Drug Regimen')
plt.ylabel('Mouse ID/ Timepoint Rows')

plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_counts = combined_data['Drug Regimen'].value_counts()

plt.bar(drug_counts.index, drug_counts.values, color='blue')

plt.title('Number of Rows for Each Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Mouse ID/ Timepoint Rows')
plt.xticks(rotation=45)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_counts = combined_data['Sex'].value_counts()
gender_counts.plot(kind='pie', colors=['skyblue', 'pink'], autopct='%1.0f%%', startangle=130)
plt.title('Distribution of Female vs. Male Mice')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_counts = combined_data['Sex'].value_counts()
plt.pie(gender_counts, labels = gender_counts.index, colors=['skyblue', 'pink'], autopct='%1.1f%%', startangle=130)
plt.title('Distribution of Female vs. Male Mice')

plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
selected_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
tumor_volume = combined_data[combined_data['Drug Regimen'].isin(regimens)]

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = tumor_volume.groupby('Mouse ID')['Timepoint'].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
tumor_volume = pd.merge(tumor_volume, last_timepoint, on=['Mouse ID', 'Timepoint'])

# %%
# Put treatments into a list for for loop (and later for plot labels)
selected_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for regimen in selected_regimens:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_volumes = combined_data.loc[combined_data['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    
    # Add subset
    tumor_vol_data.append(tumor_volumes)
    
    # Calculate the IQR and determine potential outliers using upper and lower bounds
    quartiles = tumor_volumes.quantile([0.25, 0.75])
    lower_bound = quartiles[0.25] - 1.5 * (quartiles[0.75] - quartiles[0.25])
    upper_bound = quartiles[0.75] + 1.5 * (quartiles[0.75] - quartiles[0.25])

    outliers = tumor_volumes[(tumor_volumes < lower_bound) | (tumor_volumes > upper_bound)]
    
    print(f"{regimen}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: 1652    25.472143
# 1849    23.343598
# Name: Tumor Volume (mm3), dtype: float64
# Ramicane's potential outliers: 1814    22.050126
# Name: Tumor Volume (mm3), dtype: float64
# Infubinol's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(tumor_vol_data, labels=selected_regimens)
plt.title('Distribution of Tumor Volume by Treatment Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']
mouse_id = l509
single_mouse_data = capomulin_data[capomulin_data['Mouse ID'] == mouse_id]

# Step 3: Generate the line plot of tumor volume vs. time point
plt.figure(figsize=(10, 6))
plt.plot(single_mouse_data['Timepoint'], single_mouse_data['Tumor Volume (mm3)'], marker='o')
plt.title(f'Tumor Volume vs. Time Point for Mouse {mouse_id} (Capomulin)')
plt.xlabel('Time Point')
plt.ylabel('Tumor Volume (mm3)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[211], line 4
#       1 # Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
#       3 capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']
# ----> 4 mouse_id = l509
#       5 single_mouse_data = capomulin_data[capomulin_data['Mouse ID'] == mouse_id]
#       7 # Step 3: Generate the line plot of tumor volume vs. time point
#
# NameError: name 'l509' is not defined
